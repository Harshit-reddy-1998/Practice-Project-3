# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.shape
# Out:
# (1599, 12)

# %% [markdown]
# We have 1599 rows and 12 columns.

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# We have float type values in all the independent variables and int type value in the target variable.

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# 1. the mean is higher than median in all the columns except density and quality columns.

# %% [markdown]
# 2. There is a large difference in the 75th percentile and max in free sulfur dioxide and total sulfur dioxide.

# %% [markdown]
# # To check missing values

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Here, there are no missing values.

# %% [markdown]
# # To check correlation

# %%
dfcorr=df.corr()
dfcorr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(10,5))
sns.heatmap(dfcorr,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Dark shades are highly correlated and light shades are negatively correlated.

# %% [markdown]
# # EDA

# %% [markdown]
# # Uni-Variate Analysis

# %%
k=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(3,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# Datas are almost distributed normally in this columns. Lets remove the skewness and then again plot the dist plots without skewness.

# %%
k=['total sulfur dioxide','density','pH','sulphates','alcohol']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(3,2,j)
    sns.distplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# Datas are almost distributed normally in this columns. Lets remove the skewness and then again plot the dist plots without skewness.

# %%
k=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(3,2,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# There are outliers present in all the columns.

# %%
k=['total sulfur dioxide','density','pH','sulphates','alcohol']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(3,2,j)
    sns.boxplot(df[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# There are outliers present in all the columns.

# %%
y=df[['quality']]

# %%
df.nunique()
# Out:
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
df.drop('quality',axis=1,inplace=True)

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# dtype: float64

# %% [markdown]
# We can say that there is skewness present in most of the columns.

# %%
df_new=df.copy(deep=True)

# %%
for col in df_new.columns:
    percentiles = df_new[col].quantile([0.01, 0.99]).values
    df_new[col][df_new[col] <= percentiles[0]] = percentiles[0]
    df_new[col][df_new[col] >= percentiles[1]] = percentiles[1]

# %%
df_new.skew()
# Out:
# fixed acidity           0.838324
# volatile acidity        0.443636
# citric acid             0.271976
# residual sugar          2.930041
# chlorides               4.561016
# free sulfur dioxide     1.043678
# total sulfur dioxide    1.160092
# density                 0.016993
# pH                      0.077514
# sulphates               1.398443
# alcohol                 0.796035
# dtype: float64

# %%
#outlier analysis
for column_name in df_new.columns:
    q1 = df_new[column_name].quantile(0.25)
    q3 = df_new[column_name].quantile(0.75)
    iqr = q3-q1
    upper = q3 +1.5*iqr
    lower = q1 -1.5*iqr
    outliner_df = df_new.loc[(df_new[column_name] < lower)| (df_new[column_name] > upper)]
    print('Percentage of outlier in {0} is {1}'.format(column_name, outliner_df.shape[0]/df_new.shape[0]))
# Out:
# Percentage of outlier in fixed acidity is 0.030644152595372107
# Percentage of outlier in volatile acidity is 0.011882426516572859
# Percentage of outlier in citric acid is 0.0
# Percentage of outlier in residual sugar is 0.0969355847404628
# Percentage of outlier in chlorides is 0.06441525953721075
# Percentage of outlier in free sulfur dioxide is 0.01876172607879925
# Percentage of outlier in total sulfur dioxide is 0.03439649781113196
# Percentage of outlier in density is 0.028142589118198873
# Percentage of outlier in pH is 0.013133208255159476
# Percentage of outlier in sulphates is 0.03689806128830519
# Percentage of outlier in alcohol is 0.0

# %%
k=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(3,2,j)
    sns.distplot(df_new[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# Datas are distributed normally in this columns.

# %%
k=['total sulfur dioxide','density','pH','sulphates','alcohol']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(3,2,j)
    sns.distplot(df_new[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# Datas are distributed normally in this columns.

# %%
k=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(3,2,j)
    sns.boxplot(df_new[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# There are outliers present in this columns.

# %%
k=['total sulfur dioxide','density','pH','sulphates','alcohol']
j=1
plt.figure(figsize=(10,5))
for i in k:
    plt.subplot(3,2,j)
    sns.boxplot(df_new[i])
    plt.title(i)
    j=j+1
plt.tight_layout()

# %% [markdown]
# There are outliers present in this columns.

# %%
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_new['quality']=y['quality']

# %%
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # Bi-Variate Analysis

# %%
sns.scatterplot(df_new['fixed acidity'],df_new['volatile acidity'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='volatile acidity'>

# %%
sns.scatterplot(df_new['fixed acidity'],df_new['density'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='density'>

# %% [markdown]
# This plot is positively correlated.

# %%
sns.scatterplot(df_new['fixed acidity'],df_new['pH'])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='pH'>

# %% [markdown]
# This plot is negatively correlated.

# %%
sns.scatterplot(df_new['chlorides'],df_new['residual sugar'])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='residual sugar'>

# %% [markdown]
# This plot says that there are some outliers present in it.

# %%
sns.scatterplot(df_new['citric acid'],df_new['density'])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='density'>

# %% [markdown]
# # Multi-Variate Analysis

# %%
sns.pairplot(df_new)

# %% [markdown]
# Bringing the target variable into my new dataset

# %%
df1=df_new
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
import numpy as np
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
# array([[0.53614398, 0.99770674, 1.39952902, ..., 0.62364877, 0.97248598,
#         0.78782264],
#        [0.30049411, 2.03410466, 1.39952902, ..., 0.16013789, 0.59128332,
#         0.78782264],
#        [0.30049411, 1.34317271, 1.19247109, ..., 0.03580877, 0.59128332,
#         0.78782264],
#        ...,
#        [1.18418112, 0.09626884, 0.72659075, ..., 0.61734678, 0.55232468,
#         0.45084835],
#        [1.41983099, 0.6810296 , 0.77835523, ..., 0.35608456, 0.21008065,
#         0.78782264],
#        [1.36091852, 1.24782209, 1.03340165, ..., 0.02950678, 0.55232468,
#         0.45084835]])

# %%
print(np.where(z>3))
# Out:
# (array([   9,   11,   13,   14,   14,   15,   15,   17,   17,   19,   33,
#          42,   43,   57,   79,   81,   81,   83,   83,   86,   88,   91,
#          92,  106,  106,  109,  147,  151,  151,  163,  164,  169,  169,
#         181,  188,  189,  201,  219,  226,  226,  240,  258,  258,  274,
#         278,  281,  291,  307,  308,  324,  325,  339,  340,  354,  369,
#         377,  378,  396,  396,  400,  400,  413,  415,  451,  459,  480,
#         494,  501,  502,  515,  515,  515,  517,  522,  523,  541,  566,
#         567,  568,  584,  591,  595,  614,  636,  637,  639,  649,  649,
#         651,  652,  666,  672,  684,  690,  692,  692,  723,  730,  754,
#         771,  772,  776,  777,  795,  832,  889,  899,  911,  917,  923,
#         925,  926,  982, 1038, 1043, 1051, 1051, 1071, 1074, 1077, 1078,
#        1079, 1079, 1081, 1081, 1098, 1131, 1147, 1154, 1158, 1165, 1175,
#        1186, 1231, 1235, 1244, 1244, 1244, 1260, 1260, 1276, 1288, 1289,
# ...

# %%
z[1589][3]
# Out:
# 4.530071605480527

# %%
df2=df1[(z<3).all(axis=1)]
df2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df2.shape
# Out:
# (1455, 12)

# %%
df1.shape
# Out:
# (1599, 12)

# %% [markdown]
# Here, 144 rows have been removed since the outliers were present in it.

# %%
(144/1599)*100
# Out:
# 9.00562851782364

# %%
x=df2.iloc[:,0:-1]
y=df2.iloc[:,-1]

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1455, dtype: int64

# %%
x.shape
# Out:
# (1455, 11)

# %%
y.shape
# Out:
# (1455,)

# %%
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
maxAcc=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=i)
    mod=DecisionTreeClassifier()
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAcc:
        maxAcc=acc,
        maxRS=i
print('Best accuracy is',maxAcc,'on random state',maxRS)
# Out:
# Best accuracy is (0.6607843137254902,) on random state 145

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=145)

# %%
x_train.shape
# Out:
# (945, 11)

# %%
x_test.shape
# Out:
# (510, 11)

# %%
y_train.shape
# Out:
# (945,)

# %%
y_test.shape
# Out:
# (510,)

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
pred=dtc.predict(x_test)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.6509803921568628
# [[  4   7  12   1   0]
#  [  4 148  44  10   0]
#  [  1  40 151  26   2]
#  [  1   4  19  29   3]
#  [  0   1   1   2   0]]
#               precision    recall  f1-score   support
#
#            4       0.40      0.17      0.24        24
#            5       0.74      0.72      0.73       206
#            6       0.67      0.69      0.68       220
#            7       0.43      0.52      0.47        56
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.65       510
#    macro avg       0.45      0.42      0.42       510
# weighted avg       0.65      0.65      0.65       510

# %%
mnb=MultinomialNB()
mnb.fit(x_train,y_train)
pred=mnb.predict(x_test)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.4549019607843137
# [[  0   6   8  10   0]
#  [  0  96  74  36   0]
#  [  0  60 101  59   0]
#  [  0   6  15  35   0]
#  [  0   1   0   3   0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        24
#            5       0.57      0.47      0.51       206
#            6       0.51      0.46      0.48       220
#            7       0.24      0.62      0.35        56
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.45       510
#    macro avg       0.26      0.31      0.27       510
# weighted avg       0.48      0.45      0.45       510

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.49411764705882355
# [[  1  15   6   2   0]
#  [  3 128  73   2   0]
#  [  1  96 107  16   0]
#  [  1  20  20  15   0]
#  [  0   3   0   0   1]]
#               precision    recall  f1-score   support
#
#            4       0.17      0.04      0.07        24
#            5       0.49      0.62      0.55       206
#            6       0.52      0.49      0.50       220
#            7       0.43      0.27      0.33        56
#            8       1.00      0.25      0.40         4
#
#     accuracy                           0.49       510
#    macro avg       0.52      0.33      0.37       510
# weighted avg       0.48      0.49      0.48       510

# %%
svc=SVC()  # By default kernel=rbf
svc.fit(x_train,y_train)
pred=svc.predict(x_test)
print(accuracy_score(y_test,pred))
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# 0.503921568627451
# [[  0   5  19   0   0]
#  [  0  78 128   0   0]
#  [  0  41 179   0   0]
#  [  0   3  53   0   0]
#  [  0   1   3   0   0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        24
#            5       0.61      0.38      0.47       206
#            6       0.47      0.81      0.59       220
#            7       0.00      0.00      0.00        56
#            8       0.00      0.00      0.00         4
#
#     accuracy                           0.50       510
#    macro avg       0.22      0.24      0.21       510
# weighted avg       0.45      0.50      0.45       510

# %% [markdown]
# These, accuracy scores can be becaues of overfitting. Lets, check with cross-validation.

# %% [markdown]
# # Cross-Validation

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(mnb,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.48453608 0.4604811  0.4467354  0.38831615 0.38831615]
# 0.43367697594501714

# %%
score=cross_val_score(dtc,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.47079038 0.48453608 0.45360825 0.47079038 0.47079038]
# 0.47010309278350515

# %%
score=cross_val_score(knn,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.43986254 0.48109966 0.48109966 0.37457045 0.43298969]
# 0.4419243986254296

# %%
score=cross_val_score(svc,x,y,cv=5)
print(score)
print(score.mean())
# Out:
# [0.56701031 0.54295533 0.4604811  0.46391753 0.46735395]
# 0.5003436426116838

# %% [markdown]
# The difference between the accuracy and cv says that svc is working better compared to the other models.

# %% [markdown]
# # Hyper parameter tuning

# %% [markdown]
# We use this technique to improve the accuracy of the best model that we have choosen.

# %%
from sklearn.model_selection import GridSearchCV
parameters={'kernel':['linear','rbf','poly','sigmoid'],
            'C':[1,5,10]}

# %%
gs=GridSearchCV(SVC(),parameters,cv=5)
gs.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']})

# %%
print(gs.best_params_)
# Out:
# {'C': 1, 'kernel': 'linear'}

# %%
Final_model=SVC(kernel='linear')
Final_model.fit(x_train,y_train)
pred=Final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 57.05882352941176

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump('Final_model','Finalmodel1.obj')
# Out:
# ['Finalmodel1.obj']
